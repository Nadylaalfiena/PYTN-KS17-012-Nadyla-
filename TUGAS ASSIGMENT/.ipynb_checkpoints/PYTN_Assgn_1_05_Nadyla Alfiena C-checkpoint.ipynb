# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from wordcloud import WordCloud, STOPWORDS
from PIL import Image
import folium

# %%
df_can = pd.read_csv(r'C:\Users\ASUS\Downloads\london_crime_by_lsoa.csv')
df_can.head()
# Out:
#    lsoa_code     borough               major_category  \
# 0  E01001116     Croydon                     Burglary
# 1  E01001646   Greenwich  Violence Against the Person
# 2  E01000677     Bromley  Violence Against the Person
# 3  E01003774   Redbridge                     Burglary
# 4  E01004563  Wandsworth                      Robbery
#
#                 minor_category  value  year  month
# 0  Burglary in Other Buildings      0  2016     11
# 1               Other violence      0  2016     11
# 2               Other violence      0  2015      5
# 3  Burglary in Other Buildings      0  2016      3
# 4            Personal Property      0  2008      6

# %%
df_can.columns
df_can.shape
df_can.isnull().any()
df_can.describe()
# Out:
#               value          year         month
# count  1.349060e+07  1.349060e+07  1.349060e+07
# mean   4.779444e-01  2.012000e+03  6.500000e+00
# std    1.771513e+00  2.581989e+00  3.452053e+00
# min    0.000000e+00  2.008000e+03  1.000000e+00
# 25%    0.000000e+00  2.010000e+03  3.750000e+00
# 50%    0.000000e+00  2.012000e+03  6.500000e+00
# 75%    1.000000e+00  2.014000e+03  9.250000e+00
# max    3.090000e+02  2.016000e+03  1.200000e+01

# %%
count_major_category = df_can['major_category'].value_counts()
count_major_category
# Out:
# major_category
# Theft and Handling             3966300
# Violence Against the Person    3171744
# Criminal Damage                2069172
# Drugs                          1179468
# Burglary                       1043604
# Robbery                         939384
# Other Notifiable Offences       776304
# Fraud or Forgery                236520
# Sexual Offences                 108108
# Name: count, dtype: int64

# %%
df_can.head(12)
# Out:
#     lsoa_code     borough               major_category  \
# 0   E01001116     Croydon                     Burglary
# 1   E01001646   Greenwich  Violence Against the Person
# 2   E01000677     Bromley  Violence Against the Person
# 3   E01003774   Redbridge                     Burglary
# 4   E01004563  Wandsworth                      Robbery
# 5   E01001320      Ealing           Theft and Handling
# 6   E01001342      Ealing  Violence Against the Person
# 7   E01002633    Hounslow                      Robbery
# 8   E01003496      Newham              Criminal Damage
# 9   E01004177      Sutton           Theft and Handling
# 10  E01001985    Haringey           Theft and Handling
# 11  E01003076     Lambeth  Violence Against the Person
#
#                             minor_category  value  year  month
# 0              Burglary in Other Buildings      0  2016     11
# 1                           Other violence      0  2016     11
# 2                           Other violence      0  2015      5
# 3              Burglary in Other Buildings      0  2016      3
# 4                        Personal Property      0  2008      6
# 5                              Other Theft      0  2012      5
# 6                         Offensive Weapon      0  2010      7
# 7                        Personal Property      0  2013      4
# 8        Criminal Damage To Other Building      0  2013      9
# 9              Theft/Taking of Pedal Cycle      1  2016      8
# 10  Motor Vehicle Interference & Tampering      0  2013     12
# 11                          Other violence      0  2015      4

# %%
df_can.tail
# Out:
# <bound method NDFrame.tail of           lsoa_code     borough               major_category  \
# 0         E01001116     Croydon                     Burglary
# 1         E01001646   Greenwich  Violence Against the Person
# 2         E01000677     Bromley  Violence Against the Person
# 3         E01003774   Redbridge                     Burglary
# 4         E01004563  Wandsworth                      Robbery
# ...             ...         ...                          ...
# 13490599  E01000504       Brent              Criminal Damage
# 13490600  E01002504  Hillingdon                      Robbery
# 13490601  E01004165      Sutton                     Burglary
# 13490602  E01001134     Croydon                      Robbery
# 13490603  E01003413      Merton  Violence Against the Person
#
#                        minor_category  value  year  month
# 0         Burglary in Other Buildings      0  2016     11
# 1                      Other violence      0  2016     11
# 2                      Other violence      0  2015      5
# 3         Burglary in Other Buildings      0  2016      3
# 4                   Personal Property      0  2008      6
# ...                               ...    ...   ...    ...
# 13490599  Criminal Damage To Dwelling      0  2015      2
# 13490600            Personal Property      1  2015      6
# 13490601       Burglary in a Dwelling      0  2011      2
# 13490602            Business Property      0  2011      5
# 13490603                 Wounding/GBH      0  2015      6
#
# [13490604 rows x 7 columns]>

# %%
df_can.info
# Out:
# <bound method DataFrame.info of           lsoa_code     borough               major_category  \
# 0         E01001116     Croydon                     Burglary
# 1         E01001646   Greenwich  Violence Against the Person
# 2         E01000677     Bromley  Violence Against the Person
# 3         E01003774   Redbridge                     Burglary
# 4         E01004563  Wandsworth                      Robbery
# ...             ...         ...                          ...
# 13490599  E01000504       Brent              Criminal Damage
# 13490600  E01002504  Hillingdon                      Robbery
# 13490601  E01004165      Sutton                     Burglary
# 13490602  E01001134     Croydon                      Robbery
# 13490603  E01003413      Merton  Violence Against the Person
#
#                        minor_category  value  year  month
# 0         Burglary in Other Buildings      0  2016     11
# 1                      Other violence      0  2016     11
# 2                      Other violence      0  2015      5
# 3         Burglary in Other Buildings      0  2016      3
# 4                   Personal Property      0  2008      6
# ...                               ...    ...   ...    ...
# 13490599  Criminal Damage To Dwelling      0  2015      2
# 13490600            Personal Property      1  2015      6
# 13490601       Burglary in a Dwelling      0  2011      2
# 13490602            Business Property      0  2011      5
# 13490603                 Wounding/GBH      0  2015      6
#
# [13490604 rows x 7 columns]>

# %%
df_can.columns.values
# Out:
# array(['lsoa_code', 'borough', 'major_category', 'minor_category',
#        'value', 'year', 'month'], dtype=object)

# %%
df_can.index.values
# Out:
# array([       0,        1,        2, ..., 13490601, 13490602, 13490603],
#       dtype=int64)

# %%
df_can.shape
# Out:
# (13490604, 7)

# %%
df_can.isnull().sum()
# Out:
# lsoa_code         0
# borough           0
# major_category    0
# minor_category    0
# value             0
# year              0
# month             0
# dtype: int64

# %%
df_can.describe
# Out:
# <bound method NDFrame.describe of           lsoa_code     borough               major_category  \
# 0         E01001116     Croydon                     Burglary
# 1         E01001646   Greenwich  Violence Against the Person
# 2         E01000677     Bromley  Violence Against the Person
# 3         E01003774   Redbridge                     Burglary
# 4         E01004563  Wandsworth                      Robbery
# ...             ...         ...                          ...
# 13490599  E01000504       Brent              Criminal Damage
# 13490600  E01002504  Hillingdon                      Robbery
# 13490601  E01004165      Sutton                     Burglary
# 13490602  E01001134     Croydon                      Robbery
# 13490603  E01003413      Merton  Violence Against the Person
#
#                        minor_category  value  year  month
# 0         Burglary in Other Buildings      0  2016     11
# 1                      Other violence      0  2016     11
# 2                      Other violence      0  2015      5
# 3         Burglary in Other Buildings      0  2016      3
# 4                   Personal Property      0  2008      6
# ...                               ...    ...   ...    ...
# 13490599  Criminal Damage To Dwelling      0  2015      2
# 13490600            Personal Property      1  2015      6
# 13490601       Burglary in a Dwelling      0  2011      2
# 13490602            Business Property      0  2011      5
# 13490603                 Wounding/GBH      0  2015      6
#
# [13490604 rows x 7 columns]>

# %%
df_can.isnull().sum()
# Out:
# lsoa_code         0
# borough           0
# major_category    0
# minor_category    0
# value             0
# year              0
# month             0
# dtype: int64

# %%
df_can.describe()
# Out:
#               value          year         month
# count  1.349060e+07  1.349060e+07  1.349060e+07
# mean   4.779444e-01  2.012000e+03  6.500000e+00
# std    1.771513e+00  2.581989e+00  3.452053e+00
# min    0.000000e+00  2.008000e+03  1.000000e+00
# 25%    0.000000e+00  2.010000e+03  3.750000e+00
# 50%    0.000000e+00  2.012000e+03  6.500000e+00
# 75%    1.000000e+00  2.014000e+03  9.250000e+00
# max    3.090000e+02  2.016000e+03  1.200000e+01

# %%
df_can.sort_values(by="year", ascending=False, axis=0, inplace=True)

# %%
sortd = df_can[(df_can["year"] >= 2011) & (df_can["year"] <= 2016)]

# %%
df_can.head()
# Out:
#          lsoa_code               borough               major_category  \
# 0        E01001116               Croydon                     Burglary
# 7325338  E01001974              Haringey           Theft and Handling
# 7325267  E01004251         Tower Hamlets           Theft and Handling
# 1541510  E01002268              Havering  Violence Against the Person
# 1541509  E01000063  Barking and Dagenham  Violence Against the Person
#
#                                  minor_category  value  year  month
# 0                   Burglary in Other Buildings      0  2016     11
# 7325338  Motor Vehicle Interference & Tampering      0  2016     11
# 7325267                             Other Theft      1  2016      9
# 1541510                          Other violence      0  2016      6
# 1541509                              Harassment      1  2016      9

# %%
df_can.tail()
# Out:
#           lsoa_code               borough               major_category  \
# 4154815   E01000498                 Brent           Theft and Handling
# 12104783  E01003855  Richmond upon Thames  Violence Against the Person
# 1773012   E01000473                 Brent                        Drugs
# 6399334   E01001327                Ealing           Theft and Handling
# 10858330  E01000862                Camden  Violence Against the Person
#
#               minor_category  value  year  month
# 4154815   Other Theft Person      0  2008      3
# 12104783      Other violence      0  2008      4
# 1773012     Drug Trafficking      0  2008     12
# 6399334          Other Theft      1  2008     10
# 10858330        Wounding/GBH      0  2008      3

# %%
df_can
# Out:
#           lsoa_code               borough               major_category  \
# 0         E01001116               Croydon                     Burglary
# 7325338   E01001974              Haringey           Theft and Handling
# 7325267   E01004251         Tower Hamlets           Theft and Handling
# 1541510   E01002268              Havering  Violence Against the Person
# 1541509   E01000063  Barking and Dagenham  Violence Against the Person
# ...             ...                   ...                          ...
# 4154815   E01000498                 Brent           Theft and Handling
# 12104783  E01003855  Richmond upon Thames  Violence Against the Person
# 1773012   E01000473                 Brent                        Drugs
# 6399334   E01001327                Ealing           Theft and Handling
# 10858330  E01000862                Camden  Violence Against the Person
#
#                                   minor_category  value  year  month
# 0                    Burglary in Other Buildings      0  2016     11
# 7325338   Motor Vehicle Interference & Tampering      0  2016     11
# 7325267                              Other Theft      1  2016      9
# 1541510                           Other violence      0  2016      6
# 1541509                               Harassment      1  2016      9
# ...                                          ...    ...   ...    ...
# 4154815                       Other Theft Person      0  2008      3
# 12104783                          Other violence      0  2008      4
# 1773012                         Drug Trafficking      0  2008     12
# 6399334                              Other Theft      1  2008     10
# 10858330                            Wounding/GBH      0  2008      3
#
# [13490604 rows x 7 columns]

# %%
crime = df_can.pivot_table(index='year', columns='major_category', values='value', aggfunc=np.sum, fill_value=0)
crime
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18080\3818943988.py:1: FutureWarning: The provided callable <function sum at 0x0000017EFE73A8E0> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass 'sum' instead.
#   crime = df_can.pivot_table(index='year', columns='major_category', values='value', aggfunc=np.sum, fill_value=0)
# major_category  Burglary  Criminal Damage  Drugs  Fraud or Forgery  \
# year
# 2008               88092            91872  68804              5325
# 2009               90619            85565  60549                 0
# 2010               86826            77897  58674                 0
# 2011               93315            70914  57550                 0
# 2012               93392            62158  51776                 0
# 2013               87222            56206  50278                 0
# 2014               76053            59279  44435                 0
# 2015               70489            62976  39785                 0
# 2016               68285            64071  38914                 0
#
# major_category  Other Notifiable Offences  Robbery  Sexual Offences  \
# year
# 2008                                10112    29627             1273
# 2009                                10644    29568                0
# 2010                                10768    32341                0
# 2011                                10264    36679                0
# 2012                                10675    35260                0
# 2013                                10811    29337                0
# 2014                                13037    22150                0
# 2015                                14229    21383                0
# 2016                                15809    22528                0
#
# major_category  Theft and Handling  Violence Against the Person
# year
# 2008                        283692                       159844
# 2009                        279492                       160777
# 2010                        290924                       157894
# 2011                        309292                       146901
# 2012                        334054                       150014
# 2013                        306372                       146181
# 2014                        279880                       185349
# 2015                        284022                       218740
# 2016                        294133                       232381

# %%
major_crime = crime.transpose()
major_crime
# Out:
# year                           2008    2009    2010    2011    2012    2013  \
# major_category
# Burglary                      88092   90619   86826   93315   93392   87222
# Criminal Damage               91872   85565   77897   70914   62158   56206
# Drugs                         68804   60549   58674   57550   51776   50278
# Fraud or Forgery               5325       0       0       0       0       0
# Other Notifiable Offences     10112   10644   10768   10264   10675   10811
# Robbery                       29627   29568   32341   36679   35260   29337
# Sexual Offences                1273       0       0       0       0       0
# Theft and Handling           283692  279492  290924  309292  334054  306372
# Violence Against the Person  159844  160777  157894  146901  150014  146181
#
# year                           2014    2015    2016
# major_category
# Burglary                      76053   70489   68285
# Criminal Damage               59279   62976   64071
# Drugs                         44435   39785   38914
# Fraud or Forgery                  0       0       0
# Other Notifiable Offences     13037   14229   15809
# Robbery                       22150   21383   22528
# Sexual Offences                   0       0       0
# Theft and Handling           279880  284022  294133
# Violence Against the Person  185349  218740  232381

# %%
crime['Total Crime'] = crime.sum(axis=1, numeric_only=True)
crime
# Out:
# major_category  Burglary  Criminal Damage  Drugs  Fraud or Forgery  \
# year
# 2008               88092            91872  68804              5325
# 2009               90619            85565  60549                 0
# 2010               86826            77897  58674                 0
# 2011               93315            70914  57550                 0
# 2012               93392            62158  51776                 0
# 2013               87222            56206  50278                 0
# 2014               76053            59279  44435                 0
# 2015               70489            62976  39785                 0
# 2016               68285            64071  38914                 0
#
# major_category  Other Notifiable Offences  Robbery  Sexual Offences  \
# year
# 2008                                10112    29627             1273
# 2009                                10644    29568                0
# 2010                                10768    32341                0
# 2011                                10264    36679                0
# 2012                                10675    35260                0
# 2013                                10811    29337                0
# 2014                                13037    22150                0
# 2015                                14229    21383                0
# 2016                                15809    22528                0
#
# major_category  Theft and Handling  Violence Against the Person  Total Crime
# year
# 2008                        283692                       159844       738641
# 2009                        279492                       160777       717214
# 2010                        290924                       157894       715324
# 2011                        309292                       146901       724915
# 2012                        334054                       150014       737329
# 2013                        306372                       146181       686407
# 2014                        279880                       185349       680183
# 2015                        284022                       218740       711624
# 2016                        294133                       232381       736121

# %%
major_crime.columns
# Out:
# Index([2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016], dtype='int64', name='year')

# %%
major_crime.columns = list(map(str, major_crime.columns))

# %%
years = list(map(str, range(2008, 2017)))
years
# Out:
# ['2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016']

# %%
borough = df_can.pivot_table(index='year', columns='borough', values='value', aggfunc=np.sum, fill_value=0)
borough
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18080\2051716713.py:1: FutureWarning: The provided callable <function sum at 0x0000017EFE73A8E0> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass 'sum' instead.
#   borough = df_can.pivot_table(index='year', columns='borough', values='value', aggfunc=np.sum, fill_value=0)
# borough  Barking and Dagenham  Barnet  Bexley  Brent  Bromley  Camden  \
# year
# 2008                    17656   23944   15305  23504    24015   32010
# 2009                    17713   23449   14445  24748    21858   31612
# 2010                    17130   23416   13166  25512    19572   31804
# 2011                    16686   24007   11325  27669    19868   33956
# 2012                    15990   23573   11669  26357    19622   31472
# 2013                    15759   22510   11552  23759    18945   28435
# 2014                    15426   22572   11844  24426    19668   27198
# 2015                    16346   24036   11990  24883    20637   29477
# 2016                    16741   24684   12840  26693    20164   29183
#
# borough  City of London  Croydon  Ealing  Enfield  ...  Merton  Newham  \
# year                                               ...
# 2008                  0    29516   28947    21980  ...   13875   29752
# 2009                  0    29784   28617    21147  ...   13561   28610
# 2010                  0    29373   31360    20808  ...   13595   30728
# 2011                 69    29830   29537    21041  ...   13548   27978
# 2012                157    30189   28832    21069  ...   12856   30067
# 2013                110    27444   25917    21574  ...   11595   27577
# 2014                115    27357   24978    21700  ...   11596   28005
# 2015                151    28089   26247    22076  ...   12273   29217
# 2016                178    28712   27127    22485  ...   12755   30090
#
# borough  Redbridge  Richmond upon Thames  Southwark  Sutton  Tower Hamlets  \
# year
# 2008         20873                 11106      33470   12943          23578
# 2009         20837                 10618      30623   12240          21959
# 2010         20652                 10601      31320   12032          23072
# 2011         21994                 10896      30723   11068          24712
# 2012         21424                 11168      30737   10948          26784
# 2013         19793                 10439      31128   10057          26258
# 2014         19590                 10456      28912   10443          25504
# 2015         18897                 10413      30260   10598          27493
# 2016         19502                 11074      31636   10658          29253
#
# borough  Waltham Forest  Wandsworth  Westminster
# year
# 2008              24080       23330        47846
# 2009              24761       23021        48456
# 2010              24818       22815        48116
# 2011              23714       21384        54243
# 2012              22647       24457        59226
# 2013              21903       22290        53852
# 2014              20271       21364        47564
# 2015              20969       22401        47395
# 2016              20716       23679        48330
#
# [9 rows x 33 columns]

# %%
crime_borough = borough.transpose()
crime_borough.head()
# Out:
# year                   2008   2009   2010   2011   2012   2013   2014   2015  \
# borough
# Barking and Dagenham  17656  17713  17130  16686  15990  15759  15426  16346
# Barnet                23944  23449  23416  24007  23573  22510  22572  24036
# Bexley                15305  14445  13166  11325  11669  11552  11844  11990
# Brent                 23504  24748  25512  27669  26357  23759  24426  24883
# Bromley               24015  21858  19572  19868  19622  18945  19668  20637
#
# year                   2016
# borough
# Barking and Dagenham  16741
# Barnet                24684
# Bexley                12840
# Brent                 26693
# Bromley               20164

# %%
crime_borough.columns = list(map(str, crime_borough.columns))

# %%
major_crime['Total'] = major_crime.sum(axis=1, numeric_only=True)
major_crime
# Out:
#                                2008    2009    2010    2011    2012    2013  \
# major_category
# Burglary                      88092   90619   86826   93315   93392   87222
# Criminal Damage               91872   85565   77897   70914   62158   56206
# Drugs                         68804   60549   58674   57550   51776   50278
# Fraud or Forgery               5325       0       0       0       0       0
# Other Notifiable Offences     10112   10644   10768   10264   10675   10811
# Robbery                       29627   29568   32341   36679   35260   29337
# Sexual Offences                1273       0       0       0       0       0
# Theft and Handling           283692  279492  290924  309292  334054  306372
# Violence Against the Person  159844  160777  157894  146901  150014  146181
#
#                                2014    2015    2016    Total
# major_category
# Burglary                      76053   70489   68285   754293
# Criminal Damage               59279   62976   64071   630938
# Drugs                         44435   39785   38914   470765
# Fraud or Forgery                  0       0       0     5325
# Other Notifiable Offences     13037   14229   15809   106349
# Robbery                       22150   21383   22528   258873
# Sexual Offences                   0       0       0     1273
# Theft and Handling           279880  284022  294133  2661861
# Violence Against the Person  185349  218740  232381  1558081

# %%
major_crime.tail(6).plot(kind='bar', figsize=(10,6), color='green')
plt.show()

# %%
total_crime = crime['Total Crime']
total_crime
# Out:
# year
# 2008    738641
# 2009    717214
# 2010    715324
# 2011    724915
# 2012    737329
# 2013    686407
# 2014    680183
# 2015    711624
# 2016    736121
# Name: Total Crime, dtype: int64

# %%
total_crime.head(3)
# Out:
# year
# 2008    738641
# 2009    717214
# 2010    715324
# Name: Total Crime, dtype: int64

# %%
total_crime.plot(kind='box', figsize=(10, 12), grid=True)

plt.title('Box plot of Burglary Crime from 2008-2016')
plt.ylabel('Number of Crime')

plt.show()

# %%
plt.plot(total_crime, "b--", total_crime, "ro")
plt.grid(True)

plt.title('Changes in Crime Incidents from 2008-2016')
plt.ylabel('Number of Crime')
plt.xlabel('Years')

plt.show()

# %%
major_crime.sort_values(by='Total', ascending=False, axis=0, inplace=True)

# untuk mendapatkan 5 kategori teratas
top5_crime = major_crime.head()

# transpose data
top5_crime = top5_crime[years].transpose()

top5_crime
# Out:
# major_category  Theft and Handling  Violence Against the Person  Burglary  \
# 2008                        283692                       159844     88092
# 2009                        279492                       160777     90619
# 2010                        290924                       157894     86826
# 2011                        309292                       146901     93315
# 2012                        334054                       150014     93392
# 2013                        306372                       146181     87222
# 2014                        279880                       185349     76053
# 2015                        284022                       218740     70489
# 2016                        294133                       232381     68285
#
# major_category  Criminal Damage  Drugs
# 2008                      91872  68804
# 2009                      85565  60549
# 2010                      77897  58674
# 2011                      70914  57550
# 2012                      62158  51776
# 2013                      56206  50278
# 2014                      59279  44435
# 2015                      62976  39785
# 2016                      64071  38914

# %%
top5_crime.index = top5_crime.index.map(int)

# %%
top5_crime.plot(kind='area',
                alpha=0.75,
                stacked=False,
                figsize=(20,10), # pass a tuple (x,y) size
                )

plt.title('Top 5 Major Category', fontsize=15)
plt.ylabel('Number of Crime', fontsize=15)
plt.xlabel('Years', fontsize=15)

plt.show()

# %%
major_crime['2016'].head()
# Out:
# major_category
# Theft and Handling             294133
# Violence Against the Person    232381
# Burglary                        68285
# Criminal Damage                 64071
# Drugs                           38914
# Name: 2016, dtype: int64

# %%
# np.histograms mengeluarkan 2 nilai
count, bin_edges = np.histogram(major_crime['2016'])

# print jumlah frekuensi
print(count)
# bin ranges, default = 10 bins
print(bin_edges)
# Out:
# [4 1 2 0 0 0 0 1 0 1]
# [     0.   29413.3  58826.6  88239.9 117653.2 147066.5 176479.8 205893.1
#  235306.4 264719.7 294133. ]

# %%
count, bin_edges = np.histogram(major_crime['2012'])

major_crime['2012'].plot(kind='hist', figsize=(8,5), xticks=bin_edges, yticks=count)

plt.title('Histogram of Crime from 9 Major Category in 2016')
plt.ylabel('Number of Major Category')
plt.xlabel('Number of Crime')

plt.show()

# %%
top5 = major_crime['2008'].head(3)

# %%
colors_list = ['red', 'blue', 'yellow']
# jarak antar data pada pie chart
explode_list = [.02, 0, 0] 

top5.plot(kind='pie',
          figsize=(15, 6),
          autopct='%1.1f%%', 
          startangle=90,    
          shadow=True,       
          labels=None,         
          pctdistance=1.12,    
          colors=colors_list,  
          explode=explode_list 
         )

plt.title('Top 3 Major Crime in 2016', y=1.12) 
plt.axis('equal') 

# add legend
plt.legend(labels=top5.index, loc='upper left') 

plt.show()
